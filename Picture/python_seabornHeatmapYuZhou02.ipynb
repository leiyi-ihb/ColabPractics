# %% [markdown]
# <a href="https://colab.research.google.com/github/leiyi-ihb/ColabPractics/blob/main/Picture/python_seabornHeatmapYuZhou02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
# %matplotlib inline
sns.set(font_scale=1.5)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# import os
file = pd.read_csv("/content/drive/My Drive/20221029-Yu-HSV-HTDNA-transformed-aftermedianed.csv", index_col=0)
# file.head()
# print(file.columns)
# print(file.iloc[:, 4])
print(file.iloc[0:5,0:5])
# print(file.head())
# print(file2.iloc[0:2,0:2])
# Out:
#            0h-Mock01  0h-Mock02  0h-Mock03    0h-HT01    0h-HT02
# Name
# Adenosine   0.049691   0.057170   0.049532   0.093145   0.103657
# ADP        12.152916  12.721548  11.748584  10.329068  12.037479
# AMP         5.144199   5.327099   5.477777   4.935624   4.587020
# ATP         9.583938  12.667884   9.307268   6.846281   8.185305
# cAMP        0.002753   0.001206   0.001368   0.003125   0.002611

# %%
import numpy as np
df_log10 = np.log2(file) #对数转化https://cloud.tencent.com/developer/ask/sof/296062，这个是以10为底的对数
# print(df_log10.iloc[0:5, 0:5])
file3 = df_log10.iloc[0:54,]
print(file3.iloc[0:5, 0:5])
file3.describe()
# Out:
#            0h-Mock01  0h-Mock02  0h-Mock03   0h-HT01   0h-HT02
# Name
# Adenosine  -4.330865  -4.128601  -4.335498 -3.424382 -3.270112
# ADP         3.603231   3.669202   3.554415  3.368638  3.589461
# AMP         2.362946   2.413350   2.453590  2.303233  2.197557
# ATP         3.260619   3.663104   3.218358  2.775321  3.033036
# cAMP       -8.504998  -9.694974  -9.514220 -8.321700 -8.581433
#        0h-Mock01  0h-Mock02  0h-Mock03    0h-HT01    0h-HT02    0h-HT03  \
# count  54.000000  54.000000  54.000000  54.000000  54.000000  54.000000
# mean   -1.047968  -1.038930  -1.076741  -0.908658  -0.829259  -0.976996
# std     3.212242   3.255572   3.370590   3.159477   3.124841   3.230112
# min    -8.504998  -9.694974  -9.514220  -8.321700  -8.581433  -9.627402
# 25%    -3.419257  -3.724008  -3.296599  -2.370117  -2.366960  -2.634580
# 50%    -0.809746  -1.000150  -0.653853  -0.667221  -0.765152  -0.757095
# 75%     1.571727   1.507954   1.387399   1.700825   1.774170   1.541271
# max     5.729496   5.783596   5.693682   5.590067   5.672965   5.620435
#
#        6h-Mock01  6h-Mock02  6h-Mock03    6h-HT01    6h-HT02    6h-HT03  \
# count  54.000000  54.000000  54.000000  54.000000  54.000000  54.000000
# mean   -1.435111  -1.307555  -1.343177  -1.032862       -inf  -1.038569
# std     3.280053   3.329281   3.239898   3.148305        NaN   3.181471
# min    -9.157482 -10.574731  -8.412935 -10.038618       -inf -10.187554
# 25%    -3.901909  -3.792569  -3.761878  -2.833657  -2.762339  -2.720989
# 50%    -1.510077  -1.135146  -1.319052  -0.608364  -0.748814  -0.587918
# 75%     1.311495   1.370150   1.293766   1.294173   1.346658   1.090291
# max     5.186373   5.352606   5.493087   4.765900   4.867340   5.188233
#
#        12h-Mock01  12h-Mock02  12h-Mock03   12h-HT01   12h-HT02   12h-HT03
# count   54.000000   54.000000   54.000000  54.000000  54.000000  54.000000
# mean    -1.508017   -1.410174   -1.298197  -1.062452  -0.995980  -1.070953
# std      3.181155    3.198655    3.271632   3.119663   3.160798   3.225781
# min     -8.868581  -10.065050   -9.458891  -8.832750  -8.852595  -9.679975
# 25%     -3.839252   -3.899394   -3.539431  -2.434524  -2.462918  -2.280308
# 50%     -1.309219   -1.264217   -0.979579  -1.000833  -0.740151  -0.666322
# 75%      0.922072    1.119595    1.271009   1.425020   1.461319   0.931543
# max      5.094630    5.076325    5.342571   5.018534   5.276636   5.305553

# %%
# 每一行的数，除以每一行头一个数

vector = np.array(file3["0h-Mock01"])
print(vector)
data = file3 / vector[:,None]
print(data.iloc[0:5, 0:5])
# print(data)
# Out:
# [-4.33086514  3.60323058  2.36294645  3.26061861 -8.50499769 -4.23107036
#  -4.35607317 -6.57785217 -3.66450513  3.59931925  2.34706678  3.26061861
#   0.01728985 -1.3747029   0.95336587 -3.47696264  5.72949637 -0.82427469
#  -0.3639163   1.62266982  1.80018447 -2.30405789 -0.50865475 -0.01749957
#  -4.19950804 -1.40949858  0.75165095 -2.8169887  -0.7952166   3.98360642
#  -6.18581001 -5.10420726 -4.58719789 -0.59568591 -5.22606928 -3.24614071
#  -6.34219094 -1.55608209  1.70178695 -2.48733384 -3.23695303 -6.10387437
#  -2.01495818  1.41890023  1.98358926  2.08607984  1.98358926 -1.43895846
#   1.11690586 -0.03083409 -1.14439914  0.67659455  1.40804094 -3.20045747]
#            0h-Mock01  0h-Mock02  0h-Mock03   0h-HT01   0h-HT02
# Name
# Adenosine        1.0   0.953297   1.001070  0.790692  0.755071
# ADP              1.0   1.018309   0.986452  0.934894  0.996179
# AMP              1.0   1.021331   1.038361  0.974729  0.930007
# ATP              1.0   1.123438   0.987039  0.851164  0.930203
# cAMP             1.0   1.139915   1.118662  0.978448  1.008987

# %%
# 双色系一：连续色
from seaborn.utils import axlabel
import matplotlib.pyplot as plt
sns.set_context({"figure.figsize":(20,20)})
# sns.heatmap(data=file3,square=True, vmin=-3,vmax=2, fmt='d', linewidths=.1, cmap='GnBu', annot=True)
# ax = sns.heatmap(file3,  linewidths=.01, vmin=-4,vmax=4, cmap='Oranges', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
ax = sns.heatmap(data,  linewidths=.01, vmin=-4,vmax=4, cmap='Oranges', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
plt.xlabel('Samples',fontsize=20, color='k') #x轴label的文本和字体大小
plt.ylabel('Metabolites',fontsize=20) #y轴label的文本和字体大小
# plt.xlabel('x_label',fontsize=20, color='k') #x轴label的文本和字体大小
# plt.ylabel('y_label',fontsize=20, color='k') #y轴label的文本和字体大小
plt.xticks(fontsize=10) #x轴刻度的字体大小（文本包含在pd_data中了）
plt.yticks(fontsize=10) #y轴刻度的字体大小（文本包含在pd_data中了）
plt.title('title',fontsize=20) #图片标题文本和字体大小

# colorbar该怎么设置？？
# cb = ax.figure.colorbar(ax.collections[0]) #显示colorbar
# cb.ax.tick_params(labelsize=10)#设置colorbar刻度字体大小
# cb.set_label('colorbar label') #设置colorbar的label
# Out:
# Text(0.5, 1.0, 'title')

# %%
x_normed = file3 / file3.max(axis=0)
print(x_normed.iloc[0:5, 0:5])
# Out:
#            0h-Mock01  0h-Mock02  0h-Mock03   0h-HT01   0h-HT02
# Name
# Adenosine  -0.755889  -0.713847  -0.761458 -0.612583 -0.576438
# ADP         0.628891   0.634415   0.624274  0.602611  0.632731
# AMP         0.412418   0.417275   0.430932  0.412022  0.387374
# ATP         0.569093   0.633361   0.565251  0.496474  0.534647
# cAMP       -1.484423  -1.676288  -1.671014 -1.488658 -1.512689

# %%
# 双色系一：连续色
from seaborn.utils import axlabel
import matplotlib.pyplot as plt
sns.set_context({"figure.figsize":(20,20)})
# sns.heatmap(data=file3,square=True, vmin=-3,vmax=2, fmt='d', linewidths=.1, cmap='GnBu', annot=True)
# ax = sns.heatmap(file3,  linewidths=.01, vmin=-4,vmax=4, cmap='Oranges', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
ax = sns.heatmap(x_normed,  linewidths=.01, vmin=-1,vmax=1, cmap='Oranges', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
plt.xlabel('Samples',fontsize=20, color='k') #x轴label的文本和字体大小
plt.ylabel('Metabolites',fontsize=20) #y轴label的文本和字体大小
# plt.xlabel('x_label',fontsize=20, color='k') #x轴label的文本和字体大小
# plt.ylabel('y_label',fontsize=20, color='k') #y轴label的文本和字体大小
plt.xticks(fontsize=10) #x轴刻度的字体大小（文本包含在pd_data中了）
plt.yticks(fontsize=10) #y轴刻度的字体大小（文本包含在pd_data中了）
plt.title('title',fontsize=20) #图片标题文本和字体大小

# colorbar该怎么设置？？
# cb = ax.figure.colorbar(ax.collections[0]) #显示colorbar
# cb.ax.tick_params(labelsize=10)#设置colorbar刻度字体大小
# cb.set_label('colorbar label') #设置colorbar的label
# Out:
# Text(0.5, 1.0, 'title')

# %%
sns.set()
print(data)
flights = data.pivot("0h-Mock01","0h-Mock02")

# # # species = data.pop("species")
# # #设置图片大小
# g= sns.clustermap(flights,cmap='YlGnBu', figsize=(6, 9))
# ax = g.ax_heatmap
# label_y = ax.get_yticklabels()
# plt.setp(label_y, rotation=360, horizontalalignment='left')
# #设置图片名称，分辨率，并保存
# #plt.savefig('cluster.tif', dpi=300)
# plt.show()
# Out:
#                   0h-Mock01  0h-Mock02  0h-Mock03    0h-HT01    0h-HT02  \
# CMP                1.250459   1.251677    2.270552    1.945548    1.936263
# CTP                0.219015   0.094064    0.376647    0.818083    0.948405
# cUMP               1.094756   1.027998    1.120976    1.155330    1.003411
# Cytidine           0.163992  -0.025360    2.979113    2.633086    2.244726
# Cytosine           1.110165   1.117515    1.037559    1.022804    1.098948
# dCDP               1.043995   0.992403    1.155073    1.096772    1.123096
# dCMP               1.070482   0.994824    1.178146    1.111571    1.099270
# dCTP               1.060731   1.136353    1.053819    0.959458    0.929457
# Deoxycytidine      0.811849   0.933249    1.472091    1.528086    1.177466
# Deoxyuridine       0.626315   0.809237    0.670626    0.744564    0.590049
# dI                 0.492328   0.481084    1.303557    1.250520    1.175082
# Dihydroorotate          inf   1.606315    1.038987    0.972896    1.164929
# Dihydrouracil      0.990783   0.940095    0.892866    0.864999    0.710194
# dIMP               1.102627   1.070159    1.287490    1.295600    1.220610
# Thymidine          0.416805   0.401311    0.601500    0.672628    0.384975
# Thymine            0.629978   0.602325    0.719659    0.739674    0.617431
# TMP_dTMP           0.798988   0.873898    0.899042    0.877607    0.912044
# TTP_dTTP           1.214962   1.253692    1.120592    0.920052    0.921284
# UDP                0.690513   0.469734    0.278383    0.435499    0.511080
# UDP-Gal            0.808986   0.763903    0.847029    0.937983    0.967589
# UDP-GlcNAc_GNAc    0.857562   0.861276    0.808002    0.874473    0.860159
# UDP-glucose        0.808986   0.763903    0.847029    0.937983    0.967589
# UDP-glucuronate    1.314684   1.425759    1.226986    1.141287    1.129434
# UMP                0.509063   0.831628   -0.468337   -0.029338   -0.139519
# Uracil             5.365632   7.814043   -1.078894   -2.629172  -12.929488
# Urate              1.155259   0.377913   -0.102764    0.462345   -0.403555
# Uridine            0.650774   0.673797    1.230101    0.722541    1.404857
# UTP                0.330873   0.357572    0.676119    0.913237    0.932431
# R5P-Ru5P           0.895836   1.055024    1.213235    1.161607    1.113177
#
#                    12h-HT01   12h-HT02   12h-HT03
# Name
# Adenosine          0.523290   0.527540   0.504885
# ADP                0.745963   0.748541   0.820435
# AMP                0.642955   0.712588   0.728486
# ATP                0.482827   0.455059   0.099193
# cAMP               1.032580   1.037526   1.109107
# cGMP               0.864519   1.053934   1.050322
# dADP               1.217480   1.229020   1.170540
# dAMP               1.069737   1.016398   1.040532
# Deoxyguanosine     0.368698   0.414612   0.363758
# dGDP               0.744883   0.747726   0.820050
# dGMP               0.647103   0.745862   0.728012
# dGTP               0.482827   0.455059   0.099193
# GDP              -52.220889 -40.503027 -44.255373
# GMP                1.760657   1.629816   1.620816
# Guanine            3.007563   3.160279   3.071553
# Guanosine          0.429015   0.383262   0.406240
# Hypoxanthine       0.843091   0.920960   0.926007
# IMP                1.414461   1.051792   0.685843
# Inosine            3.019305   1.301475   1.255582
# Purine             2.220047   2.260307   2.003636
# Xanthine           0.456473   0.774341   0.762369
# PRPP               0.694137   0.593754   0.682092
# Ribose            -2.453160  -2.061507  -1.977941
# CDP               50.403886  53.077829  53.186969
# CDP-Ethanolamine   0.987989   0.900879   0.893813
# CMP                1.730572   1.420395   1.558618
# CTP                0.401589   0.250507   0.179381
# cUMP               1.049888   1.006757   0.990069
# Cytidine           0.879344   0.810935   0.476204
# Cytosine           1.259797   1.251686   1.228752
# dCDP               1.060352   1.066431   1.137341
# dCMP               1.170884   1.093032   1.132679
# dCTP               1.041495   1.109647   1.099781
# Deoxycytidine      0.028207   0.115035   0.308729
# Deoxyuridine       0.549332   0.686824   0.819353
# dI                 0.368444   0.356480   0.372517
# Dihydroorotate     1.392697   1.395826   1.526282
# Dihydrouracil      0.715408   0.782304   0.722923
# dIMP               0.966368   1.124693   1.241070
# Thymidine          0.196069   0.178261   0.276281
# Thymine            0.427754   0.386374   0.494702
# TMP_dTMP           0.925358   0.873165   0.868690
# TTP_dTTP           1.063612   1.139676   1.131887
# UDP                0.438514   0.423680   0.446677
# UDP-Gal            0.748184   0.842267   0.853382
# UDP-GlcNAc_GNAc    0.816971   0.958576   0.973214
# UDP-glucose        0.748184   0.842267   0.853382
# UDP-glucuronate    1.586967   1.750171   1.583868
# UMP                0.014871   0.458706   0.355914
# Uracil            -8.157110  -2.121589   1.146154
# Urate              1.305945   0.681590   0.563999
# Uridine            0.791374   0.536652   0.757406
# UTP                0.601788   0.433521   0.502758
# R5P-Ru5P           1.006206   1.087858   0.914632
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-6fa027b956eb> in <module>
#       1 sns.set()
#       2 print(data)
# ----> 3 flights = data.pivot("0h-Mock01","0h-Mock02")
#       4
#       5 # # # species = data.pop("species")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     515         else:
#     516             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 517     return indexed.unstack(columns_listlike)
#     518
#     519
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in unstack(self, level, fill_value)
#    8322         from pandas.core.reshape.reshape import unstack
#    8323
# -> 8324         result = unstack(self, level, fill_value)
#    8325
#    8326         return result.__finalize__(self, method="unstack")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     445     if isinstance(obj, DataFrame):
#     446         if isinstance(obj.index, MultiIndex):
# --> 447             return _unstack_frame(obj, level, fill_value=fill_value)
#     448         else:
#     449             return obj.T.stack(dropna=False)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/reshape.py in _unstack_frame(obj, level, fill_value)
#     468 def _unstack_frame(obj, level, fill_value=None):
#     469     if not obj._can_fast_transpose:
# --> 470         unstacker = _Unstacker(obj.index, level=level)
#     471         mgr = obj._mgr.unstack(unstacker, fill_value=fill_value)
#     472         return obj._constructor(mgr)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/reshape.py in __init__(self, index, level, constructor)
#     131             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     132
# --> 133         self._make_selectors()
#     134
#     135     @cache_readonly
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     183
#     184         if mask.sum() < len(self.index):
# --> 185             raise ValueError("Index contains duplicate entries, cannot reshape")
#     186
#     187         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape
