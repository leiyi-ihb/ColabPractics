# %% [markdown]
# <a href="https://colab.research.google.com/github/leiyi-ihb/ColabPractics/blob/main/Picture/Copy_of_python_seabornHeatmapYuZhou.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
# %matplotlib inline
sns.set(font_scale=1.5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
# import os
file = pd.read_csv("/content/drive/My Drive/20221029-Yu-HSV-HTDNA-transformed-aftermedianed.csv", index_col=0)
# file.head()
# print(file.columns)
# print(file.iloc[:, 4])
print(file.iloc[0:5,0:5])
# print(file.head())
# print(file2.iloc[0:2,0:2])
# Out:
#            0h-Mock01  0h-Mock02  0h-Mock03    0h-HT01    0h-HT02
# Name
# Adenosine   0.049691   0.057170   0.049532   0.093145   0.103657
# ADP        12.152916  12.721548  11.748584  10.329068  12.037479
# AMP         5.144199   5.327099   5.477777   4.935624   4.587020
# ATP         9.583938  12.667884   9.307268   6.846281   8.185305
# cAMP        0.002753   0.001206   0.001368   0.003125   0.002611

# %%
import numpy as np
file2 = file.apply(np.log) #对数转换竟然同下面不一样，这个是自然对数
file3 = file2.iloc[0:54,]
print(file3.iloc[0:5, 0:5])
# Out:
#            0h-Mock01  0h-Mock02  0h-Mock03   0h-HT01   0h-HT02
# Name
# Adenosine  -3.001927  -2.861728  -3.005138 -2.373601 -2.266669
# ADP         2.497569   2.543297   2.463733  2.334962  2.488025
# AMP         1.637870   1.672807   1.700699  1.596479  1.523231
# ATP         2.260089   2.539070   2.230796  1.923706  2.102340
# cAMP       -5.895215  -6.720044  -6.594755 -5.768163 -5.948196

# %%
df_log10 = np.log10(file) #对数转化https://cloud.tencent.com/developer/ask/sof/296062，这个是以10为底的对数
# print(df_log10.iloc[0:5, 0:5])
file3 = df_log10.iloc[0:54,]
print(file3.iloc[0:5, 0:5])
file3.describe()
# Out:
#            0h-Mock01  0h-Mock02  0h-Mock03   0h-HT01   0h-HT02
# Name
# Adenosine  -1.303720  -1.242833  -1.305115 -1.030842 -0.984402
# ADP         1.084680   1.104540   1.069986  1.014061  1.080536
# AMP         0.711318   0.726491   0.738604  0.693342  0.661531
# ATP         0.981544   1.102704   0.968822  0.835455  0.913035
# cAMP       -2.560259  -2.918478  -2.864066 -2.505081 -2.583269
#        0h-Mock01  0h-Mock02  0h-Mock03    0h-HT01    0h-HT02    0h-HT03  \
# count  54.000000  54.000000  54.000000  54.000000  54.000000  54.000000
# mean   -0.315470  -0.312749  -0.324131  -0.273533  -0.249632  -0.294105
# std     0.966981   0.980025   1.014649   0.951097   0.940671   0.972361
# min    -2.560259  -2.918478  -2.864066  -2.505081  -2.583269  -2.898137
# 25%    -1.029299  -1.121038  -0.992375  -0.713476  -0.712526  -0.793088
# 50%    -0.243758  -0.301075  -0.196829  -0.200854  -0.230334  -0.227908
# 75%     0.473137   0.453939   0.417649   0.511999   0.534079   0.463969
# ...

# %%
# 双色系一：连续色
from seaborn.utils import axlabel
import matplotlib.pyplot as plt
sns.set_context({"figure.figsize":(20,20)})
# sns.heatmap(data=file3,square=True, vmin=-3,vmax=2, fmt='d', linewidths=.1, cmap='GnBu', annot=True)
# ax = sns.heatmap(file3,  linewidths=.01, vmin=-4,vmax=4, cmap='Oranges', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
ax = sns.heatmap(file3,  linewidths=.01, vmin=-4,vmax=4, cmap='RdYlBu_r', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
plt.xlabel('Samples',fontsize=20, color='k') #x轴label的文本和字体大小
plt.ylabel('Metabolites',fontsize=20) #y轴label的文本和字体大小
# plt.xlabel('x_label',fontsize=20, color='k') #x轴label的文本和字体大小
# plt.ylabel('y_label',fontsize=20, color='k') #y轴label的文本和字体大小
plt.xticks(fontsize=10) #x轴刻度的字体大小（文本包含在pd_data中了）
plt.yticks(fontsize=10) #y轴刻度的字体大小（文本包含在pd_data中了）
plt.title('title',fontsize=20) #图片标题文本和字体大小

# colorbar该怎么设置？？
# cb = ax.figure.colorbar(ax.collections[0]) #显示colorbar
# cb.ax.tick_params(labelsize=10)#设置colorbar刻度字体大小
# cb.set_label('colorbar label') #设置colorbar的label
# Out:
# Text(0.5, 1.0, 'title')

# %%
# 双色系二：间断色
from seaborn.utils import axlabel
import matplotlib.pyplot as plt
sns.set_context({"figure.figsize":(20,20)})
# sns.heatmap(data=file3,square=True, vmin=-3,vmax=2, fmt='d', linewidths=.1, cmap='GnBu', annot=True)
# ax = sns.heatmap(file3,  linewidths=.01, vmin=-4,vmax=4, cmap='Oranges', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
ax = sns.heatmap(file3,  linewidths=.01, vmin=-4,vmax=4, cmap='Pastel2_r', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
plt.xlabel('Samples',fontsize=20, color='k') #x轴label的文本和字体大小
plt.ylabel('Metabolites',fontsize=20) #y轴label的文本和字体大小
# plt.xlabel('x_label',fontsize=20, color='k') #x轴label的文本和字体大小
# plt.ylabel('y_label',fontsize=20, color='k') #y轴label的文本和字体大小
plt.xticks(fontsize=10) #x轴刻度的字体大小（文本包含在pd_data中了）
plt.yticks(fontsize=10) #y轴刻度的字体大小（文本包含在pd_data中了）
plt.title('title',fontsize=20) #图片标题文本和字体大小

# colorbar该怎么设置？？
# cb = ax.figure.colorbar(ax.collections[0]) #显示colorbar
# cb.ax.tick_params(labelsize=10)#设置colorbar刻度字体大小
# cb.set_label('colorbar label') #设置colorbar的label
# Out:
# Text(0.5, 1.0, 'title')

# %%
# 单色系二：连续色（下浅上深）
from seaborn.utils import axlabel
import matplotlib.pyplot as plt
sns.set_context({"figure.figsize":(20,20)})
# sns.heatmap(data=file3,square=True, vmin=-3,vmax=2, fmt='d', linewidths=.1, cmap='GnBu', annot=True)
ax = sns.heatmap(file3,  linewidths=.01, vmin=-4,vmax=4, cmap='Oranges', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
# ax = sns.heatmap(file3,  linewidths=.01, vmin=-4,vmax=4, cmap='Pastel2_r', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
plt.xlabel('Samples',fontsize=20, color='k') #x轴label的文本和字体大小
plt.ylabel('Metabolites',fontsize=20) #y轴label的文本和字体大小
# plt.xlabel('x_label',fontsize=20, color='k') #x轴label的文本和字体大小
# plt.ylabel('y_label',fontsize=20, color='k') #y轴label的文本和字体大小
plt.xticks(fontsize=10) #x轴刻度的字体大小（文本包含在pd_data中了）
plt.yticks(fontsize=10) #y轴刻度的字体大小（文本包含在pd_data中了）
plt.title('title',fontsize=20) #图片标题文本和字体大小

# colorbar该怎么设置？？
# cb = ax.figure.colorbar(ax.collections[0]) #显示colorbar
# cb.ax.tick_params(labelsize=10)#设置colorbar刻度字体大小
# cb.set_label('colorbar label') #设置colorbar的label
# Out:
# Text(0.5, 1.0, 'title')

# %%
# 单色系二：连续色（下深，上浅）
from seaborn.utils import axlabel
import matplotlib.pyplot as plt
sns.set_context({"figure.figsize":(20,20)})
# sns.heatmap(data=file3,square=True, vmin=-3,vmax=2, fmt='d', linewidths=.1, cmap='GnBu', annot=True)
ax = sns.heatmap(file3,  linewidths=.01, vmin=-4,vmax=4, cmap='CMRmap', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
# ax = sns.heatmap(file3,  linewidths=.01, vmin=-4,vmax=4, cmap='Pastel2_r', annot=True, annot_kws={'size':10, 'color':'black'}, cbar=True, cbar_kws={"shrink": 0.4})
plt.xlabel('Samples',fontsize=20, color='k') #x轴label的文本和字体大小
plt.ylabel('Metabolites',fontsize=20) #y轴label的文本和字体大小
# plt.xlabel('x_label',fontsize=20, color='k') #x轴label的文本和字体大小
# plt.ylabel('y_label',fontsize=20, color='k') #y轴label的文本和字体大小
plt.xticks(fontsize=10) #x轴刻度的字体大小（文本包含在pd_data中了）
plt.yticks(fontsize=10) #y轴刻度的字体大小（文本包含在pd_data中了）
plt.title('title',fontsize=20) #图片标题文本和字体大小

# colorbar该怎么设置？？
# cb = ax.figure.colorbar(ax.collections[0]) #显示colorbar
# cb.ax.tick_params(labelsize=10)#设置colorbar刻度字体大小
# cb.set_label('colorbar label') #设置colorbar的label
# Out:
# Text(0.5, 1.0, 'title')

# %%
file4 = file3.iloc[0:2,]
print(file4)
sns.set_context({"figure.figsize":(5,5)})
ax = sns.heatmap(file4, fmt='d', linewidths=.01, cmap='Oranges')
# Out:
#            0h-Mock01  0h-Mock02  0h-Mock03   0h-HT01   0h-HT02   0h-HT03  \
# Name
# Adenosine   -1.30372  -1.242833  -1.305115 -1.030842 -0.984402 -1.005804
# ADP          1.08468   1.104540   1.069986  1.014061  1.080536  1.045669
#
#            6h-Mock01  6h-Mock02  6h-Mock03   6h-HT01   6h-HT02   6h-HT03  \
# Name
# Adenosine  -1.247692  -1.148192  -1.139714 -0.878600 -0.880984 -0.838652
# ADP         0.967008   0.982497   0.959467  0.873893  0.932763  0.893952
#
#            12h-Mock01  12h-Mock02  12h-Mock03  12h-HT01  12h-HT02  12h-HT03
# Name
# Adenosine   -1.116304   -1.174663   -1.044483 -0.682223 -0.687764 -0.658228
# ADP          0.780929    0.856986    0.859886  0.809131  0.811928  0.889910

# %% [markdown]
# **参考**https://learnku.com/articles/39890

# %%
import seaborn as sns
import matplotlib.pyplot as plt
file_row0 = file.iloc[0:1]
# print(file_row0)

file_tmp=file_row0.iloc[0]
print(type(file_tmp))
print(file_tmp.index)
print(file_tmp.values)
sns.barplot(x=file_tmp.index, y=file_tmp.values, color="black")
ax.set_xticklabels(labels = file_tmp.index, rotation = 45,fontsize = 10) # 放大横轴坐标并逆时针旋转45°
# sns.barplot(file_row0)
# plt.show()
# Out:
# <class 'pandas.core.series.Series'>
# Index(['0h-Mock01', '0h-Mock02', '0h-Mock03', '0h-HT01', '0h-HT02', '0h-HT03',
#        '6h-Mock01', '6h-Mock02', '6h-Mock03', '6h-HT01', '6h-HT02', '6h-HT03',
#        '12h-Mock01', '12h-Mock02', '12h-Mock03', '12h-HT01', '12h-HT02',
#        '12h-HT03'],
#       dtype='object')
# [0.04969122 0.05716989 0.04953192 0.09314471 0.10365692 0.09867244
#  0.0565338  0.07108991 0.07249134 0.1322513  0.13152741 0.14499348
#  0.07650607 0.06688634 0.09026452 0.20786269 0.20522762 0.21967054]
# [Text(0.5, 0, '0h-Mock01'),
#  Text(2.5, 0, '0h-Mock02'),
#  Text(4.5, 0, '0h-Mock03'),
#  Text(6.5, 0, '0h-HT01'),
#  Text(8.5, 0, '0h-HT02'),
#  Text(10.5, 0, '0h-HT03'),
#  Text(12.5, 0, '6h-Mock01'),
#  Text(14.5, 0, '6h-Mock02'),
#  Text(16.5, 0, '6h-Mock03')]
