# %% [markdown]
# <a href="https://colab.research.google.com/github/leiyi-ihb/ColabPractics/blob/main/Picture/Copy_of_python_seabornHeatmapYuZhou.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
# %matplotlib inline
sns.set(font_scale=1.5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# import os
file = pd.read_csv("/content/drive/My Drive/20221029-Yu-HSV-HTDNA-transformed-aftermedianed.csv", index_col=0)
# file.head()
# print(file.columns)
# print(file.iloc[:, 4])
print(file.iloc[0:2,0:2])
# print(file.head())
# print(file2.iloc[0:2,0:2])
# Out:
#            0h-Mock01  0h-Mock02
# Name
# Adenosine   0.049691   0.057170
# ADP        12.152916  12.721548

# %%
import numpy as np
file2 = file.apply(np.log)
file3 = file2.iloc[0:54,]
print(file3)
# Out:
#                   0h-Mock01  0h-Mock02  0h-Mock03   0h-HT01   0h-HT02  \
# Name
# Adenosine         -3.001927  -2.861728  -3.005138 -2.373601 -2.266669
# ADP                2.497569   2.543297   2.463733  2.334962  2.488025
# AMP                1.637870   1.672807   1.700699  1.596479  1.523231
# ATP                2.260089   2.539070   2.230796  1.923706  2.102340
# cAMP              -5.895215  -6.720044  -6.594755 -5.768163 -5.948196
# cGMP              -2.932754  -3.625312  -6.309525 -2.666469 -2.913591
# dADP              -3.019400  -3.026627  -3.061563 -3.465310 -3.149403
# dAMP              -4.559420  -4.602141  -4.474664 -4.366712 -4.986824
# Deoxyguanosine    -2.540041  -2.675942  -2.664658 -1.407569 -1.477287
# dGDP               2.494858   2.543229   2.460625  2.332125  2.485090
# dGMP               1.626863   1.659408   1.687606  1.588078  1.511915
# dGTP               2.260089   2.538736   2.238840  1.923706  2.102340
# GDP                0.011984   0.023014  -0.038519 -0.214263 -0.095298
# GMP               -0.952871  -0.950223  -0.906137 -1.083572 -1.162433
# Guanine            0.660823   0.565554   0.663730  1.384350  1.335411
# Guanosine         -2.410047  -2.668809  -2.114360 -1.418150 -1.308350
# Hypoxanthine       3.971384   4.008883   3.946560  3.874739  3.932200
# IMP               -0.571344  -0.732876  -0.451584 -0.034070 -0.165040
# Inosine           -0.252248  -0.201250  -0.185248 -0.059641  0.000439
# Purine             1.124749  -0.369151   0.527332  2.086012  1.899247
# Xanthine           1.247793   1.239807   1.247400  0.793450  0.714888
# PRPP              -1.597051  -1.641480  -1.215972 -1.471993 -1.178504
# Ribose            -0.352573  -0.243171   0.311904  0.416506  0.335316
# CDP               -0.012130  -0.002094  -0.057743 -0.152629 -0.073364
# CDP-Ethanolamine  -2.910877  -2.854741  -2.978120 -2.951937 -2.939447
# CMP               -0.976990  -0.948263  -0.967480 -1.076794 -1.211150
# CTP                0.521005   0.673538   0.483661  0.411799  0.672556
# cUMP              -1.952588  -1.758419  -1.665800 -2.029720 -1.801658
# Cytidine          -0.551202  -0.653626  -0.454849 -0.378703 -0.491396
# Cytosine           2.761226   2.880552   2.651054  2.668322  2.646848
# dCDP              -4.287677  -4.095415  -4.057475 -4.673111 -4.210910
# dCMP              -3.537967  -3.435327  -3.503699 -3.744388 -3.808580
# UDP-glucose       1.112291  1.050305    1.164596    1.289651    1.330356
# UDP-glucuronate  -1.311278 -1.422067   -1.223808   -1.138331   -1.126509
# UMP               0.394107  0.643830   -0.362577   -0.022713   -0.108013
# Uracil           -0.114677 -0.167006    0.023059    0.056192    0.276336
# Urate            -0.916394 -0.299774    0.081516   -0.366749    0.320114
# Uridine           0.305200  0.315997    0.576892    0.338857    0.658849
# UTP               0.322926  0.348983    0.659878    0.891300    0.910034
# R5P-Ru5P         -1.987312 -2.340452   -2.691427   -2.576895   -2.469458
#
#                   12h-HT01  12h-HT02  12h-HT03
# Name
# Adenosine        -1.570878 -1.583636 -1.515626
# ADP               1.863093  1.869533  2.049094
# AMP               1.053077  1.167126  1.193166
# ATP               1.091233  1.028473  0.224184
# cAMP             -6.087279 -6.116441 -6.538425
# cGMP             -2.535422 -3.090929 -3.080337
# dADP             -3.676059 -3.710901 -3.534327
# dAMP             -4.877381 -4.634187 -4.744220
# Deoxyguanosine   -0.936507 -1.053132 -0.923960
# dGDP              1.858378  1.865469  2.045909
# dGMP              1.052748  1.213415  1.184376
# dGTP              1.091233  1.028473  0.224184
# GDP              -0.625837 -0.485405 -0.530375
# GMP              -1.677680 -1.553005 -1.544430
# Guanine           1.987466  2.088384  2.029752
# Guanosine        -1.033945 -0.923679 -0.979056
# Hypoxanthine      3.348237  3.657485  3.677529
# IMP              -0.808143 -0.600935 -0.391852
# Inosine          -0.761612 -0.328294 -0.316718
# Purine            2.496996  2.542278  2.253588
# Xanthine          0.569583  0.966217  0.951279
# PRPP             -1.108572 -0.948256 -1.089335
# Ribose            0.864917  0.726831  0.697368
# CDP              -0.611388 -0.643822 -0.645146
# CDP-Ethanolamine -2.875915 -2.622347 -2.601779
# CMP              -1.690752 -1.387712 -1.522755
# CTP               0.209230  0.130515  0.093459
# cUMP             -2.049998 -1.965781 -1.933197
# Cytidine         -0.484696 -0.446989 -0.262484
# Cytosine          3.478583  3.456187  3.392862
# dCDP             -4.546447 -4.572513 -4.876551
# dCMP             -4.142549 -3.867110 -4.007380
# dCTP             -3.311541 -3.528237 -3.496867
# Deoxycytidine    -0.011647 -0.047498 -0.127474
# Deoxyuridine     -1.989919 -2.487976 -2.968052
# dI               -0.829019 -0.802099 -0.838183
# Dihydroorotate   -6.122395 -6.136151 -6.709647
# Dihydrouracil    -0.771635 -0.843789 -0.779740
# dIMP              1.139917  1.326675  1.463952
# Thymidine        -0.338041 -0.307339 -0.476333
# Thymine          -0.959745 -0.866902 -1.109955
# TMP_dTMP         -3.915080 -3.694260 -3.675325
# TTP_dTTP         -1.485508 -1.591743 -1.580864
# UDP               0.431282  0.416692  0.439309
# UDP-Gal           1.028693  1.158049  1.173331
# UDP-GlcNAc_GNAc   1.181307  1.386063  1.407228
# UDP-glucose       1.028693  1.158049  1.173331
# UDP-glucuronate  -1.582857 -1.745638 -1.579766
# UMP               0.011513  0.355121  0.275542
# Uracil            0.174338  0.045344 -0.024496
# Urate            -1.035924 -0.540662 -0.447385
# Uridine           0.371138  0.251679  0.355208
# UTP               0.587333  0.423108  0.490682
# R5P-Ru5P         -2.232156 -2.413292 -2.029009

# %%
import numpy as np
file2 = file.apply(np.log)
file4 = file2.iloc[0:2,]
print(file4)
# Out:
#            0h-Mock01  0h-Mock02  0h-Mock03   0h-HT01   0h-HT02   0h-HT03  \
# Name
# Adenosine  -3.001927  -2.861728  -3.005138 -2.373601 -2.266669 -2.315950
# ADP         2.497569   2.543297   2.463733  2.334962  2.488025  2.407742
#
#            6h-Mock01  6h-Mock02  6h-Mock03   6h-HT01   6h-HT02   6h-HT03  \
# Name
# Adenosine  -2.872917  -2.643810  -2.624288 -2.023051 -2.028540 -1.931066
# ADP         2.226618   2.262283   2.209255  2.012214  2.147767  2.058400
#
#            12h-Mock01  12h-Mock02  12h-Mock03  12h-HT01  12h-HT02  12h-HT03
# Name
# Adenosine   -2.570385   -2.704761   -2.405011 -1.570878 -1.583636 -1.515626
# ADP          1.798157    1.973283    1.979962  1.863093  1.869533  2.049094

# %%
sns.set_context({"figure.figsize":(20,20)})
# sns.heatmap(data=file3,square=True, vmin=-1,vmax=1, cmap='GnBu')
ax = sns.heatmap(file3, fmt='d', linewidths=.01, cmap='Oranges')

# %%
sns.set_context({"figure.figsize":(5,5)})
ax = sns.heatmap(file4, fmt='d', linewidths=.01, cmap='Oranges')

# %% [markdown]
# **参考**https://learnku.com/articles/39890

# %%
import seaborn as sns
import matplotlib.pyplot as plt
file_row0 = file.iloc[0:1]
# print(file_row0)

file_tmp=file_row0.iloc[0]
print(type(file_tmp))
print(file_tmp.index)
print(file_tmp.values)
sns.barplot(x=file_tmp.index, y=file_tmp.values, color="black")
ax.set_xticklabels(labels = file_tmp.index, rotation = 45,fontsize = 10) # 放大横轴坐标并逆时针旋转45°
# sns.barplot(file_row0)
# plt.show()
# Out:
# <class 'pandas.core.series.Series'>
# Index(['0h-Mock01', '0h-Mock02', '0h-Mock03', '0h-HT01', '0h-HT02', '0h-HT03',
#        '6h-Mock01', '6h-Mock02', '6h-Mock03', '6h-HT01', '6h-HT02', '6h-HT03',
#        '12h-Mock01', '12h-Mock02', '12h-Mock03', '12h-HT01', '12h-HT02',
#        '12h-HT03'],
#       dtype='object')
# [0.04969122 0.05716989 0.04953192 0.09314471 0.10365692 0.09867244
#  0.0565338  0.07108991 0.07249134 0.1322513  0.13152741 0.14499348
#  0.07650607 0.06688634 0.09026452 0.20786269 0.20522762 0.21967054]
# [Text(0.5, 0, '0h-Mock01'),
#  Text(2.5, 0, '0h-Mock02'),
#  Text(4.5, 0, '0h-Mock03'),
#  Text(6.5, 0, '0h-HT01'),
#  Text(8.5, 0, '0h-HT02'),
#  Text(10.5, 0, '0h-HT03'),
#  Text(12.5, 0, '6h-Mock01'),
#  Text(14.5, 0, '6h-Mock02'),
#  Text(16.5, 0, '6h-Mock03')]
