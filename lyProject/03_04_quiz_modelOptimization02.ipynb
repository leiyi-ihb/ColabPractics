# %% [markdown]
# <a href="https://colab.research.google.com/github/leiyi-ihb/ColabPractics/blob/main/lyProject/03_04_quiz_modelOptimization02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# validation the modles found from 03script
# Different results showed in same model
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, MaxPooling1D, GlobalMaxPooling1D, Conv1D, Flatten, AveragePooling1D, GlobalAveragePooling1D
from keras.optimizers import Adam, SGD

# %%
! if [ ! -f "dataset_Li.pkl" ]; then wget https://master.dl.sourceforge.net/project/summer-research-20/sim_data_1/dataset_Li.pkl ; else echo "Found previous downloaded data."; fi
# Out:
# Found previous downloaded data.

# %%
# Data processing
import pickle
with open("dataset_Li.pkl", "rb") as f:
    data = pickle.load(f)
x_train, y_train = np.array(data['train'][0]), np.array(data['train'][1])
x_test, y_test = np.array(data['test'][0]), np.array(data['test'][1])

print(x_train.shape)
# Out:
# (16000, 1000, 4)

# %%
class Model:  
  def __init__(self, learnRate):        
    '''optimizer'''
    self.adam = Adam(lr=learnRate)
    self.sgd = SGD(lr=learnRate) 
    self.model = Sequential()

  def modelBuild(self, filter, poolSize, kernelSize, ConvAct, DenAct, input):
    model = self.model
    '''model build'''   
    model.add(Conv1D(filters=filter, kernel_size=(kernelSize), activation=ConvAct, input_shape=input))
    model.add(MaxPooling1D(pool_size=(poolSize)))
    model.add(GlobalMaxPooling1D())
    model.add(Flatten())
    model.add(Dense(32, activation=DenAct))
    model.add(Dense(1, activation=DenAct))
    print(model.summary())

  def modelCompile(self, met, los):
    '''model compile'''
    model = self.model
    model.compile(optimizer=self.adam,
             metrics = [met],
             loss = los)

  def modelFit(self, xTrain, yTrain, epo, batSize): 
    '''model fix'''
    model = self.model 
    model.fit(xTrain, 
              yTrain,
              epochs = epo,
              batch_size = batSize
              )
    
  def modelEvaluate(self, xTrain, yTrain, xTest, yTest, batSize):
    '''model evaluate'''
    model = self.model
    loss, accuracy = model.evaluate(xTrain, yTrain, batch_size=batSize)
    print("\ntest loss:", loss)
    print('accuracy:', accuracy)

    loss, accuracy = model.evaluate(xTest, yTest) #将我们的训练集也评估一下
    print("\ntrain loss:", loss)
    print('accuracy:', accuracy)



if __name__=='__main__':
  '''
  1, Conv1d: Filters = {32, 16, 3}; Kernel_size = {20, 10, 7, 5, 3}; Activation = {‘relu’, ‘tanh’, ‘linear’}
  2, Pooling1d: Max or Avg pool; Pool size = {8, 4, 2,}
  3, Flatten: Global Max, Global Avg, Flatten
  4, Dense: Units = {32, 64}; Activation = {‘relu’, ‘tanh’, ‘linear’}
  '''
  kernel_size =[20, 10, 7, 5, 3]
  activation = ["relu", "tanh", "linear"]
  poolSize = [8, 4, 2]
  deAct = ["relu", "tanh", "linear"]



  obj1 = Model(0.01)
  # obj1.modelBuild(filter=32, poolSize=i[2], kernelSize=i[0], ConvAct=i[1], DenAct=i[3], input=(1000, 4))
  obj1.modelBuild(filter=32, poolSize=2, kernelSize=20, ConvAct="tanh", DenAct="tanh", input=(1000, 4))
  obj1.modelCompile(met="acc", los='binary_crossentropy')
  obj1.modelFit(xTrain=x_train, yTrain=y_train, epo=10, batSize=512)
  obj1.modelEvaluate(xTrain=x_train, yTrain=y_train, xTest=x_test, yTest=y_test, batSize=512)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_9 (Conv1D)           (None, 981, 32)           2592
#
#  max_pooling1d_9 (MaxPooling  (None, 490, 32)          0
#  1D)
#
#  global_max_pooling1d_9 (Glo  (None, 32)               0
#  balMaxPooling1D)
#
#  flatten_9 (Flatten)         (None, 32)                0
#
#  dense_18 (Dense)            (None, 32)                1056
#
#  dense_19 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 3,681
# Trainable params: 3,681
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 32/32 [==============================] - 17s 517ms/step - loss: 2.0075 - acc: 0.5017
# Epoch 2/10
# 32/32 [==============================] - 17s 518ms/step - loss: 0.7298 - acc: 0.4928
# Epoch 3/10
# 32/32 [==============================] - 19s 607ms/step - loss: 0.6920 - acc: 0.5175
# Epoch 4/10
# 32/32 [==============================] - 17s 515ms/step - loss: 0.6836 - acc: 0.5882
# Epoch 5/10
# 32/32 [==============================] - 16s 505ms/step - loss: 0.6191 - acc: 0.7279
# Epoch 6/10
# 32/32 [==============================] - 16s 506ms/step - loss: 0.3663 - acc: 0.9014
# Epoch 7/10
# 32/32 [==============================] - 18s 548ms/step - loss: 0.2123 - acc: 0.9379
# Epoch 8/10
# 32/32 [==============================] - 17s 518ms/step - loss: 3.3343 - acc: 0.6684
# Epoch 9/10
# 32/32 [==============================] - 16s 514ms/step - loss: 5.2144 - acc: 0.4997
# Epoch 10/10
# 32/32 [==============================] - 16s 512ms/step - loss: 4.3324 - acc: 0.4997
# 32/32 [==============================] - 5s 137ms/step - loss: 3.8652 - acc: 0.4997
#
# test loss: 3.865245819091797
# accuracy: 0.4996874928474426
# 63/63 [==============================] - 1s 14ms/step - loss: 3.8164 - acc: 0.5060
#
# train loss: 3.816401720046997
# accuracy: 0.5059999823570251

# %% [markdown]
# **解决03_04脚本中结果不可重复的问题：**查阅[资料](https://www.jiqixuexishequ.com/how-to-use-keras-to-get-reproducible-results.html)在脚本中我们在脚本的最开始两行固定了随机数种子，但结果显示问题还是存在。因此我们在下一个脚本【03_04_quiz_modelOptimization02.ipynb】中，准备在模型开始处固定随机数种子，发现结果就稳定了。

# %%
class Model:  
  def __init__(self, learnRate):        
    '''optimizer'''
    self.adam = Adam(lr=learnRate)
    self.sgd = SGD(lr=learnRate) 
    self.model = Sequential()

  def modelBuild(self, filter, poolSize, kernelSize, ConvAct, DenAct, input):
    model = self.model
    '''model build'''   
    model.add(Conv1D(filters=filter, kernel_size=(kernelSize), activation=ConvAct, input_shape=input))
    model.add(MaxPooling1D(pool_size=(poolSize)))
    model.add(GlobalMaxPooling1D())
    model.add(Flatten())
    model.add(Dense(32, activation=DenAct))
    model.add(Dense(1, activation=DenAct))
    print(model.summary())

  def modelCompile(self, met, los):
    '''model compile'''
    model = self.model
    model.compile(optimizer=self.adam,
             metrics = [met],
             loss = los)

  def modelFit(self, xTrain, yTrain, epo, batSize): 
    '''model fix'''
    model = self.model 
    model.fit(xTrain, 
              yTrain,
              epochs = epo,
              batch_size = batSize
              )
    
  def modelEvaluate(self, xTrain, yTrain, xTest, yTest, batSize):
    '''model evaluate'''
    model = self.model
    loss, accuracy = model.evaluate(xTrain, yTrain, batch_size=batSize)
    print("\ntest loss:", loss)
    print('accuracy:', accuracy)

    loss, accuracy = model.evaluate(xTest, yTest) #将我们的训练集也评估一下
    print("\ntrain loss:", loss)
    print('accuracy:', accuracy)



if __name__=='__main__':
  '''
  1, Conv1d: Filters = {32, 16, 3}; Kernel_size = {20, 10, 7, 5, 3}; Activation = {‘relu’, ‘tanh’, ‘linear’}
  2, Pooling1d: Max or Avg pool; Pool size = {8, 4, 2,}
  3, Flatten: Global Max, Global Avg, Flatten
  4, Dense: Units = {32, 64}; Activation = {‘relu’, ‘tanh’, ‘linear’}
  '''
  kernel_size =[20, 10, 7, 5, 3]
  activation = ["relu", "tanh", "linear"]
  poolSize = [8, 4, 2]
  deAct = ["relu", "tanh", "linear"]

  from itertools import product
  loop_val = [kernel_size, activation, poolSize, deAct] #
  for i in product(*loop_val):
    print(x_train.shape)
    print(i)
    if i == (20, 'tanh', 2, 'tanh'):
      obj1 = Model(0.01)
      obj1.modelBuild(filter=32, poolSize=i[2], kernelSize=i[0], ConvAct=i[1], DenAct=i[3], input=(1000, 4))
      obj1.modelCompile(met="acc", los='binary_crossentropy')
      obj1.modelFit(xTrain=x_train, yTrain=y_train, epo=10, batSize=512)
      obj1.modelEvaluate(xTrain=x_train, yTrain=y_train, xTest=x_test, yTest=y_test, batSize=512)
# Out:
# (16000, 1000, 4)
# (20, 'relu', 8, 'relu')
# (16000, 1000, 4)
# (20, 'relu', 8, 'tanh')
# (16000, 1000, 4)
# (20, 'relu', 8, 'linear')
# (16000, 1000, 4)
# (20, 'relu', 4, 'relu')
# (16000, 1000, 4)
# (20, 'relu', 4, 'tanh')
# (16000, 1000, 4)
# (20, 'relu', 4, 'linear')
# (16000, 1000, 4)
# (20, 'relu', 2, 'relu')
# (16000, 1000, 4)
# (20, 'relu', 2, 'tanh')
# (16000, 1000, 4)
# (20, 'relu', 2, 'linear')
# (16000, 1000, 4)
# (20, 'tanh', 8, 'relu')
# (16000, 1000, 4)
# (20, 'tanh', 8, 'tanh')
# (16000, 1000, 4)
# (20, 'tanh', 8, 'linear')
# (16000, 1000, 4)
# (20, 'tanh', 4, 'relu')
# (16000, 1000, 4)
# (20, 'tanh', 4, 'tanh')
# (16000, 1000, 4)
# (20, 'tanh', 4, 'linear')
# (16000, 1000, 4)
# (20, 'tanh', 2, 'relu')
# (16000, 1000, 4)
# (20, 'tanh', 2, 'tanh')
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 981, 32)           2592
#
#  max_pooling1d_1 (MaxPooling  (None, 490, 32)          0
#  1D)
#
#  global_max_pooling1d_1 (Glo  (None, 32)               0
#  balMaxPooling1D)
#
#  flatten_1 (Flatten)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 32)                1056
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 3,681
# Trainable params: 3,681
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 32/32 [==============================] - 14s 420ms/step - loss: 7.4860 - acc: 0.5002
# Epoch 2/10
# 32/32 [==============================] - 13s 419ms/step - loss: 7.7077 - acc: 0.5003
# Epoch 3/10
# 32/32 [==============================] - 13s 419ms/step - loss: 7.7077 - acc: 0.5003
# Epoch 4/10
# 32/32 [==============================] - 13s 420ms/step - loss: 7.7077 - acc: 0.5003
# Epoch 5/10
# 32/32 [==============================] - 14s 422ms/step - loss: 7.7077 - acc: 0.5003
# Epoch 6/10
# 32/32 [==============================] - 13s 418ms/step - loss: 7.7077 - acc: 0.5003
# Epoch 7/10
# 32/32 [==============================] - 13s 420ms/step - loss: 7.7077 - acc: 0.5003
# Epoch 8/10
# 32/32 [==============================] - 15s 456ms/step - loss: 7.7077 - acc: 0.5003
# Epoch 9/10
# 32/32 [==============================] - 13s 420ms/step - loss: 7.7077 - acc: 0.5003
# Epoch 10/10
# 32/32 [==============================] - 13s 421ms/step - loss: 7.7077 - acc: 0.5003
# 32/32 [==============================] - 4s 109ms/step - loss: 7.7077 - acc: 0.5003
#
# test loss: 7.707653999328613
# accuracy: 0.5003125071525574
# 63/63 [==============================] - 1s 10ms/step - loss: 7.8050 - acc: 0.4940
#
# train loss: 7.805024147033691
# accuracy: 0.49399998784065247
# (16000, 1000, 4)
# (20, 'tanh', 2, 'linear')
# (16000, 1000, 4)
# (20, 'linear', 8, 'relu')
# (16000, 1000, 4)
# (20, 'linear', 8, 'tanh')
# (16000, 1000, 4)
# (20, 'linear', 8, 'linear')
# (16000, 1000, 4)
# (20, 'linear', 4, 'relu')
# (16000, 1000, 4)
# (20, 'linear', 4, 'tanh')
# (16000, 1000, 4)
# (20, 'linear', 4, 'linear')
# (16000, 1000, 4)
# (20, 'linear', 2, 'relu')
# (16000, 1000, 4)
# (20, 'linear', 2, 'tanh')
# (16000, 1000, 4)
# (20, 'linear', 2, 'linear')
# (16000, 1000, 4)
# (10, 'relu', 8, 'relu')
# (16000, 1000, 4)
# (10, 'relu', 8, 'tanh')
# (16000, 1000, 4)
# (10, 'relu', 8, 'linear')
# (16000, 1000, 4)
# (10, 'relu', 4, 'relu')
# (16000, 1000, 4)
# (10, 'relu', 4, 'tanh')
# (16000, 1000, 4)
# (10, 'relu', 4, 'linear')
# (16000, 1000, 4)
# (10, 'relu', 2, 'relu')
# (16000, 1000, 4)
# (10, 'relu', 2, 'tanh')
# (16000, 1000, 4)
# (10, 'relu', 2, 'linear')
# (16000, 1000, 4)
# (10, 'tanh', 8, 'relu')
# (16000, 1000, 4)
# (10, 'tanh', 8, 'tanh')
# (16000, 1000, 4)
# (10, 'tanh', 8, 'linear')
# (16000, 1000, 4)
# (10, 'tanh', 4, 'relu')
# (16000, 1000, 4)
# (10, 'tanh', 4, 'tanh')
# (16000, 1000, 4)
# (10, 'tanh', 4, 'linear')
# (16000, 1000, 4)
# (10, 'tanh', 2, 'relu')
# (16000, 1000, 4)
# (10, 'tanh', 2, 'tanh')
# (16000, 1000, 4)
# (10, 'tanh', 2, 'linear')
# (16000, 1000, 4)
# (10, 'linear', 8, 'relu')
# (16000, 1000, 4)
# (10, 'linear', 8, 'tanh')
# (16000, 1000, 4)
# (10, 'linear', 8, 'linear')
# (16000, 1000, 4)
# (10, 'linear', 4, 'relu')
# (16000, 1000, 4)
# (10, 'linear', 4, 'tanh')
# (16000, 1000, 4)
# (10, 'linear', 4, 'linear')
# (16000, 1000, 4)
# (10, 'linear', 2, 'relu')
# (16000, 1000, 4)
# (10, 'linear', 2, 'tanh')
# (16000, 1000, 4)
# (10, 'linear', 2, 'linear')
# (16000, 1000, 4)
# (7, 'relu', 8, 'relu')
# (16000, 1000, 4)
# (7, 'relu', 8, 'tanh')
# (16000, 1000, 4)
# (7, 'relu', 8, 'linear')
# (16000, 1000, 4)
# (7, 'relu', 4, 'relu')
# (16000, 1000, 4)
# (7, 'relu', 4, 'tanh')
# (16000, 1000, 4)
# (7, 'relu', 4, 'linear')
# (16000, 1000, 4)
# (7, 'relu', 2, 'relu')
# (16000, 1000, 4)
# (7, 'relu', 2, 'tanh')
# (16000, 1000, 4)
# (7, 'relu', 2, 'linear')
# (16000, 1000, 4)
# (7, 'tanh', 8, 'relu')
# (16000, 1000, 4)
# (7, 'tanh', 8, 'tanh')
# (16000, 1000, 4)
# (7, 'tanh', 8, 'linear')
# (16000, 1000, 4)
# (7, 'tanh', 4, 'relu')
# (16000, 1000, 4)
# (7, 'tanh', 4, 'tanh')
# (16000, 1000, 4)
# (7, 'tanh', 4, 'linear')
# (16000, 1000, 4)
# (7, 'tanh', 2, 'relu')
# (16000, 1000, 4)
# (7, 'tanh', 2, 'tanh')
# (16000, 1000, 4)
# (7, 'tanh', 2, 'linear')
# (16000, 1000, 4)
# (7, 'linear', 8, 'relu')
# (16000, 1000, 4)
# (7, 'linear', 8, 'tanh')
# (16000, 1000, 4)
# (7, 'linear', 8, 'linear')
# (16000, 1000, 4)
# (7, 'linear', 4, 'relu')
# (16000, 1000, 4)
# (7, 'linear', 4, 'tanh')
# (16000, 1000, 4)
# (7, 'linear', 4, 'linear')
# (16000, 1000, 4)
# (7, 'linear', 2, 'relu')
# (16000, 1000, 4)
# (7, 'linear', 2, 'tanh')
# (16000, 1000, 4)
# (7, 'linear', 2, 'linear')
# (16000, 1000, 4)
# (5, 'relu', 8, 'relu')
# (16000, 1000, 4)
# (5, 'relu', 8, 'tanh')
# (16000, 1000, 4)
# (5, 'relu', 8, 'linear')
# (16000, 1000, 4)
# (5, 'relu', 4, 'relu')
# (16000, 1000, 4)
# (5, 'relu', 4, 'tanh')
# (16000, 1000, 4)
# (5, 'relu', 4, 'linear')
# (16000, 1000, 4)
# (5, 'relu', 2, 'relu')
# (16000, 1000, 4)
# (5, 'relu', 2, 'tanh')
# (16000, 1000, 4)
# (5, 'relu', 2, 'linear')
# (16000, 1000, 4)
# (5, 'tanh', 8, 'relu')
# (16000, 1000, 4)
# (5, 'tanh', 8, 'tanh')
# (16000, 1000, 4)
# (5, 'tanh', 8, 'linear')
# (16000, 1000, 4)
# (5, 'tanh', 4, 'relu')
# (16000, 1000, 4)
# (5, 'tanh', 4, 'tanh')
# (16000, 1000, 4)
# (5, 'tanh', 4, 'linear')
# (16000, 1000, 4)
# (5, 'tanh', 2, 'relu')
# (16000, 1000, 4)
# (5, 'tanh', 2, 'tanh')
# (16000, 1000, 4)
# (5, 'tanh', 2, 'linear')
# (16000, 1000, 4)
# (5, 'linear', 8, 'relu')
# (16000, 1000, 4)
# (5, 'linear', 8, 'tanh')
# (16000, 1000, 4)
# (5, 'linear', 8, 'linear')
# (16000, 1000, 4)
# (5, 'linear', 4, 'relu')
# (16000, 1000, 4)
# (5, 'linear', 4, 'tanh')
# (16000, 1000, 4)
# (5, 'linear', 4, 'linear')
# (16000, 1000, 4)
# (5, 'linear', 2, 'relu')
# (16000, 1000, 4)
# (5, 'linear', 2, 'tanh')
# (16000, 1000, 4)
# (5, 'linear', 2, 'linear')
# (16000, 1000, 4)
# (3, 'relu', 8, 'relu')
# (16000, 1000, 4)
# (3, 'relu', 8, 'tanh')
# (16000, 1000, 4)
# (3, 'relu', 8, 'linear')
# (16000, 1000, 4)
# (3, 'relu', 4, 'relu')
# (16000, 1000, 4)
# (3, 'relu', 4, 'tanh')
# (16000, 1000, 4)
# (3, 'relu', 4, 'linear')
# (16000, 1000, 4)
# (3, 'relu', 2, 'relu')
# (16000, 1000, 4)
# (3, 'relu', 2, 'tanh')
# (16000, 1000, 4)
# (3, 'relu', 2, 'linear')
# (16000, 1000, 4)
# (3, 'tanh', 8, 'relu')
# (16000, 1000, 4)
# (3, 'tanh', 8, 'tanh')
# (16000, 1000, 4)
# (3, 'tanh', 8, 'linear')
# (16000, 1000, 4)
# (3, 'tanh', 4, 'relu')
# (16000, 1000, 4)
# (3, 'tanh', 4, 'tanh')
# (16000, 1000, 4)
# (3, 'tanh', 4, 'linear')
# (16000, 1000, 4)
# (3, 'tanh', 2, 'relu')
# (16000, 1000, 4)
# (3, 'tanh', 2, 'tanh')
# (16000, 1000, 4)
# (3, 'tanh', 2, 'linear')
# (16000, 1000, 4)
# (3, 'linear', 8, 'relu')
# (16000, 1000, 4)
# (3, 'linear', 8, 'tanh')
# (16000, 1000, 4)
# (3, 'linear', 8, 'linear')
# (16000, 1000, 4)
# (3, 'linear', 4, 'relu')
# (16000, 1000, 4)
# (3, 'linear', 4, 'tanh')
# (16000, 1000, 4)
# (3, 'linear', 4, 'linear')
# (16000, 1000, 4)
# (3, 'linear', 2, 'relu')
# (16000, 1000, 4)
# (3, 'linear', 2, 'tanh')
# (16000, 1000, 4)
# (3, 'linear', 2, 'linear')
